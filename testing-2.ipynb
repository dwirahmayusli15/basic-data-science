# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline

import pandas as pd
data = pd.io.parsers.read_csv("E:\\studentperformance.csv")
df = pd.read_csv("E:\\studentperformance.csv")
df.head(51)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %%
data.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
data.sample(frac=0.1)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 946    male        group B                 high school      standard
# 582  female        group D           bachelor's degree  free/reduced
# 786  female        group E            some high school  free/reduced
# 975  female        group C                some college      standard
# 642  female        group B            some high school  free/reduced
# 690  female        group C          associate's degree      standard
# 908  female        group C           bachelor's degree  free/reduced
# 712  female        group D                some college      standard
# 510    male        group D                some college      standard
# 710    male        group C                some college      standard
# 448    male        group B                 high school      standard
# 124    male        group E                some college      standard
# 147    male        group C          associate's degree  free/reduced
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# gender                         1000 non-null object
# race/ethnicity                 1000 non-null object
# parental level of education    1000 non-null object
# lunch                          1000 non-null object
# test preparation course        1000 non-null object
# math score                     1000 non-null int64
# reading score                  1000 non-null int64
# writing score                  1000 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 43.0+ KB

# %%
data.iloc[:,0:3].dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# dtype: object

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
data.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
data.corr()
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
data.iloc[:,1:].corr()
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
data.isnull().values.any()
# Out:
# False

# %%
data.isnull().sum()
for i,col in enumerate(data.columns):
    print(i+1,". column is ",col)
# Out:
# 1 . column is  gender
# 2 . column is  race/ethnicity
# 3 . column is  parental level of education
# 4 . column is  lunch
# 5 . column is  test preparation course
# 6 . column is  math score
# 7 . column is  reading score
# 8 . column is  writing score

# %%
data.rename(columns=({'gender':'Gender','race/ethnicity':'Race/Ethnicity'
                     ,'parental level of education':'Parental_Level_of_Education'
                     ,'lunch':'Lunch','test preparation course':'Test_Preparation_Course'
                      ,'math score':'Math_Score','reading score':'Reading_Score'
                     ,'writing score':'Writing_Score'}),inplace=True)

# %%
for i,col in enumerate(data.columns):
    print(i+1,". column is ",col)
# Out:
# 1 . column is  Gender
# 2 . column is  Race/Ethnicity
# 3 . column is  Parental_Level_of_Education
# 4 . column is  Lunch
# 5 . column is  Test_Preparation_Course
# 6 . column is  Math_Score
# 7 . column is  Reading_Score
# 8 . column is  Writing_Score

# %%
data['Gender'].value_counts()
# Out:
# female    518
# male      482
# Name: Gender, dtype: int64

# %%
data['Gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
sns.set(style='whitegrid')
ax=sns.barplot(x=data['Gender'].value_counts().index,y=data['Gender'].value_counts().values,palette="Blues_d",hue=['female','male'])
plt.legend(loc=8)
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.title('Perbandingan Siswa Perempuan dan Laki-laki Test Preparation',color='black',fontsize=14)
plt.show()

# %%
sns.barplot(x=data['Gender'].value_counts().index,y=data['Gender'].value_counts().values)
plt.title('Perbandingan Siswa Perempuan dan Laki-laki Mengikuti Test Preparation',color='black',fontsize=14)
plt.ylabel('Rates')
plt.legend(loc=0)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
labels=data['Race/Ethnicity'].value_counts().index
colors=['blue','red','yellow','green','brown']
explode=[0,0,0.1,0,0]
values=data['Race/Ethnicity'].value_counts().values

#visualization
plt.figure(figsize=(5,5))
plt.pie(values,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%')
plt.title('Persentase Ethnic Mendapatkan Math Score > 55',color='black',fontsize=14)
plt.show()

# %%
plt.figure(figsize=(4,4))
labels=['Math Score', 'Reading Score', 'Writing Score']
colors=['blue','red','yellow']
explode=[0,0,0.1]
values=[data.Math_Score.mean(),data.Reading_Score.mean(),data.Writing_Score.mean()]

plt.pie(values,labels=labels,colors=colors,explode=explode,autopct='%1.1f%%',shadow=True)
plt.legend(['Math Score', 'Reading Score', 'Writing Score'] , loc=3)
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
labels = 'group A', 'group B', 'group C', 'group D','group E'
sizes = data.groupby('Race/Ethnicity')['Reading_Score'].mean().values
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0,0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Reading Score for Every Race/Ethnicity Mean')
plt.axis('equal')
plt.show()

# %%
f, ax = plt.subplots(figsize=(5, 5))
sns.despine(f, left=True, bottom=True)
sns.scatterplot(x="Writing_Score", y="Reading_Score",
                hue="Gender", size="Gender",data=data)
plt.title('Grafik Titik antara Reading Score dengan Writing Score',color='black',fontsize=14)
plt.show()

# %%
import numpy as np
import pandas as pd 
from sqlalchemy import create_engine

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv("E://studentperformance.csv")
data= data.head(1000)

print(data)

engine = create_engine('sqlite:///:memory:')
data.to_sql('siswatest', engine)
# Out:
#      gender     race parental level of education         lunch  \
# 0    female  group B           bachelor's degree      standard
# 1    female  group C                some college      standard
# 2    female  group B             master's degree      standard
# 3      male  group A          associate's degree  free/reduced
# 4      male  group C                some college      standard
# 5    female  group B          associate's degree      standard
# 6    female  group B                some college      standard
# 7      male  group B                some college  free/reduced
# 8      male  group D                 high school  free/reduced
# 9    female  group B                 high school  free/reduced
# 10     male  group C          associate's degree      standard
# 11     male  group D          associate's degree      standard
# 12   female  group B                 high school      standard
# 13     male  group A                some college      standard
# ...

# %%
result = pd.read_sql_query('SELECT COUNT("math_score") as Jumlah, race as Etnic  FROM siswatest GROUP BY race HAVING COUNT("math_score") > 55', engine);
plt.pie(result['Jumlah'], labels=result['Etnic'], autopct ='% 1.1f %%', shadow = True)
plt.title('Perbandingan Siswa  berdasarkan Etnic yang memiliki nilai >55')
plt.legend()


plt.title('Perbandingan Siswa Berdasarkan Etnic yang Memiliki Nilai Matematika >55')
plt.legend(loc='upper center', bbox_to_anchor=(1.4, 1), shadow=True)

plt.legend(result['race'], loc='upper center', bbox_to_anchor=(1.3, 1), shadow=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'race'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-97-b4590c48d3c6> in <module>
# ...
